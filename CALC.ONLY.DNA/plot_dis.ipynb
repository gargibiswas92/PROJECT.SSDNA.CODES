# %%
inp1 = open('new_dis_001.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation1', fontsize=20)
plt.savefig('sim1.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_002.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation2', fontsize=20)
plt.savefig('sim2.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_003.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation3', fontsize=20)
plt.savefig('sim3.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_004.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation4', fontsize=20)
plt.savefig('sim4.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_005.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation5', fontsize=20)
plt.savefig('sim5.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_006.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation6', fontsize=20)
plt.savefig('sim6.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_007.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation7', fontsize=20)
plt.savefig('sim7.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_008.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation8', fontsize=20)
plt.savefig('sim8.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_009.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation9', fontsize=20)
plt.savefig('sim9.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_010.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation10', fontsize=20)
plt.savefig('sim10.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_011.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation11', fontsize=20)
plt.savefig('sim11.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_012.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation12', fontsize=20)
plt.savefig('sim12.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_013.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation13', fontsize=20)
plt.savefig('sim13.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_014.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation14', fontsize=20)
plt.savefig('sim14.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_015.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation15', fontsize=20)
plt.savefig('sim15.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_016.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation16', fontsize=20)
plt.savefig('sim16.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_017.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation17', fontsize=20)
plt.savefig('sim17.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_018.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation18', fontsize=20)
plt.savefig('sim18.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_019.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation19', fontsize=20)
plt.savefig('sim19.png', dpi=300, bbox_inches='tight')

# %%
inp1 = open('new_dis_020.txt', 'r')
n1 = []
n2 = []
n3 = []
n4 = []
n5 = []
t = []
count = 0
for line in inp1:
    arr = line.split()
    n1.append(float(arr[1]))
    n2.append(float(arr[2]))
    n3.append(float(arr[3]))
    n4.append(float(arr[4]))
    n5.append(float(arr[5]))
    count = count + 1
    t.append(count)
    
import matplotlib.pyplot as plt
import matplotlib.pyplot 
plt.plot(t,n1, label='contact_1')
plt.plot(t,n2, label='contact_2')
plt.plot(t,n3, label='contact_3')
plt.plot(t,n4, label='contact_4')
plt.plot(t,n5, label='contact_5')

plt.xlabel('Time steps', fontsize=16)
plt.ylabel('Distance between ends ($\AA$)', fontsize=16)
plt.legend()
plt.title('Simulation20', fontsize=20)
plt.savefig('sim20.png', dpi=300, bbox_inches='tight')
